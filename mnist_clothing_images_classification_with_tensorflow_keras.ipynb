# %%
import tensorflow
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.3.0

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
print(f"the shape of the training images are : {train_images.shape}")
print(f"the shape of the test images are : {test_images.shape}")
# Out:
# the shape of the training images are : (60000, 28, 28)
# the shape of the test images are : (10000, 28, 28)

# %%
train_labels, test_labels
# Out:
# (array([5, 0, 4, ..., 5, 6, 8], dtype=uint8),
#  array([7, 2, 1, ..., 4, 5, 6], dtype=uint8))

# %%
print(f"the shape of the test images are : {train_labels.shape}")
print(f"the shape of the test labels are : {test_labels.shape}")
# Out:
# the shape of the test images are : (60000,)
# the shape of the test labels are : (10000,)

# %%
type(train_labels.shape)
# Out:
# tuple

# %%
# Let's have a look at the first 10 samples of the training images

for i in range(10):
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.show()

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(512, activation='relu', input_shape=(28 * 28,)),
    layers.Dense(256, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer ="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=['accuracy'])

# %%
train_images = train_images.reshape((60000, 28*28)).astype(np.float32)/255
test_images = test_images.reshape((10000, 28*28)).astype(np.float32)/255

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 6s 98us/sample - loss: 0.2287 - acc: 0.9304
# Epoch 2/5
# 60000/60000 [==============================] - 6s 98us/sample - loss: 0.0831 - acc: 0.9737
# Epoch 3/5
# 60000/60000 [==============================] - 6s 96us/sample - loss: 0.0542 - acc: 0.9831
# Epoch 4/5
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.0396 - acc: 0.9876
# Epoch 5/5
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.0289 - acc: 0.9904

# %%
History.history

# %%
test_test = test_images[0:10]

predictions = model.predict(test_test)

print(predictions[0])
# Out:
# [9.4801909e-12 3.2760772e-09 2.3673259e-08 2.8680645e-06 2.8302320e-13
#  1.2102301e-09 5.7662689e-16 9.9999630e-01 1.0143512e-09 7.7815184e-07]

# %%
print(predictions[0].argmax())
# Out:
# 7

# %%
test_labels[0] # verify label 0 equals to 7
# Out:
# 7
